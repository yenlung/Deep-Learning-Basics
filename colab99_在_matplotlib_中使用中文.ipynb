# %% [markdown]
# <a href="https://colab.research.google.com/github/yenlung/Deep-Learning-Basics/blob/master/colab99_%E5%9C%A8_matplotlib_%E4%B8%AD%E4%BD%BF%E7%94%A8%E4%B8%AD%E6%96%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab 預設環境中並沒有中文字型, 所以我們需要上傳一個中文字型。然後把這字型加入 `matplotlib` 字型家族中。

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 為了字型事宜, 我們再加入直接呼叫 `matplotlib` 的選項。

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

# %% [markdown]
# ### 1. 下載一個中文字型到 Colab
#
# 我們這裡以翰字鑄造的[台北黑體](https://sites.google.com/view/jtfoundry/)為例, 這裡選了 regular 的版本。

# %%
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# --2021-07-14 09:55:40--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 108.177.13.101, 108.177.13.113, 108.177.13.138, ...
# Connecting to drive.google.com (drive.google.com)|108.177.13.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/alngrlpae0iol8rhfa5vpbbnd8ea6odv/1626256500000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_ [following]
# Warning: wildcards not supported in HTTP.
# --2021-07-14 09:55:42--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/alngrlpae0iol8rhfa5vpbbnd8ea6odv/1626256500000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 173.194.215.132, 2607:f8b0:400c:c0c::84
# Connecting to doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)|173.194.215.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-font-ttf]
# Saving to: ‘TaipeiSansTCBeta-Regular.ttf’
#
# TaipeiSansTCBeta-Re     [ <=>                ]  19.70M  --.-KB/s    in 0.1s
#
# 2021-07-14 09:55:42 (158 MB/s) - ‘TaipeiSansTCBeta-Regular.ttf’ saved [20659344]

# %% [markdown]
# 你當然可以上傳自己的字型。
#
# ![image.png](data:image/png;base64,...)
#
# 比如上傳了 `NotoSansCJKtc-Medium.otf` 字型。

# %% [markdown]
# 加入 `matplotlib` 字體。

# %%
fm.fontManager.addfont('TaipeiSansTCBeta-Regular.ttf')
mpl.rc('font', family='Taipei Sans TC Beta')

# %% [markdown]
# 如果是你自己上傳了 `NotoSansCJKtc-Medium.otf` 檔案, 就是這樣下指令。
#
# ```python
# fm.fontManager.addfont('NotoSansCJKtc-Medium.otf')
# mpl.rc('font', family='Noto Sans CJK TC')
# ```

# %% [markdown]
# 我們怎麼知道字型正確的名稱呢? 可以看一下目前 `matplotlib` 的字型名稱, 也順便確定我們裝好了。
#
# ```python
# [f.name for f in fm.fontManager.ttflist]
# ```

# %% [markdown]
# ### 2. 畫個圖試試看

# %%
x = np.linspace(-2*np.pi, 2* np.pi, 200)
y = np.sin(x)

# %%
plt.title('可愛的 $\sin$ 我要看到中文')
plt.plot(x,y)

# %% [markdown]
# ### 3. `seabron` 也要顯示中文

# %%
import seaborn as sns

# %%
sns.set(font="Taipei Sans TC Beta")

# %%
plt.title('可愛的 $\sin$ 我要看到中文')
plt.plot(x,y)

# %% [markdown]
# ### 4. 我們再把畫圖轉回給 `matplotlib`

# %%
sns.reset_orig()

# %%
plt.title('可愛的 $\sin$ 我要看到中文')
plt.plot(x,y)
