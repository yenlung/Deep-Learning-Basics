# %% [markdown]
# ![Jupyter 工作室.001.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ### 1. 讀入基本套件

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. 基本運算

# %%
egg = np.array([1,2,3,4])

# %%
egg**2
# Out:
# array([ 1,  4,  9, 16])

# %%
egg = np.array([[1, 2], [3, 4]])

# %%
egg
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# ### 3. 畫個函數的圖形

# %%
x = np.linspace(-10, 10, 200)
y = np.sin(x)

# %%
plt.plot(x, y);

# %% [markdown]
# ### 4. 畫出資料

# %%
y = np.sin(x) + 0.3 * np.random.randn(200)

# %%
plt.scatter(x, y)
